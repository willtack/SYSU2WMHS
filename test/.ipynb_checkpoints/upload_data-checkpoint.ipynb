# %% [markdown]
# ## Upload example data
# The purpose of the notebooks in this folder are to test the performance of the SYSU2 algorithm using Flywheel. First, we need to upload the data from this BOX folder: https://upenn.app.box.com/s/yhrwuy6x1iqcu0n81zimrrd6jvmyglmx/folder/140187582132 in a structured way.

# %%
# Import packages
import logging
import os
from pathlib import Path
import re
import time
import flywheel

# %%
# Instantiate a logger
logging.basicConfig(level=logging.INFO, format='%(asctime)s %(levelname)s %(message)s')
log = logging.getLogger('root')

# %%
# Instantiate the Flywheel API client
fw = flywheel.Client()

# %%
# Initialize some values
PROJECT_LABEL = 'WMHtestgearSYSU2'
GROUP_LABEL = 'detre_group'
PATH_TO_DATA = Path('test-data')

# %%
def get_or_create_subject(project, label, update=True, **kwargs):
    """Get the Subject container if it exists, else create a new Subject container.
    
    Args:
        project (flywheel.Project): A Flywheel Project.
        label (str): The subject label.
        update (bool): If true, update container with key/value passed as kwargs.
        kwargs (dict): Any key/value properties of subject you would like to update.

    Returns:
        (flywheel.Subject): A Flywheel Subject container.
    """
    
    if not label:
        raise ValueError(f'label is required (currently {label})')
        
    subject = project.subjects.find_first(f'label={label}')
    if not subject:
        subject = project.add_subject(label=label)
        
    if update and kwargs:
        subject.update(**kwargs)

    if subject:
        subject = subject.reload()

    return subject

# %%
def get_or_create_session(subject, label, update=True, **kwargs):
    """Get the Session container if it exists, else create a new Session container.
    
    Args:
        subject (flywheel.Subject): A Flywheel Subject.
        label (str): The session label.
        update (bool): If true, update container with key/value passed as kwargs.        
        kwargs (dict): Any key/value properties of Session you would like to update.

    Returns:
        (flywheel.Session): A flywheel Session container.
    """
    
    if not label:
        raise ValueError(f'label is required (currently {label})')
        
    session = subject.sessions.find_first(f'label={label}')
    if not session:
        session = subject.add_session(label=label)
        
    if update and kwargs:
        session.update(**kwargs)

    if session:
        session = session.reload()

    return session

# %%
def get_or_create_acquisition(session, label, update=True, **kwargs):
    """Get the Acquisition container if it exists, else create a new Acquisition container.
    
    Args:
        session (flywheel.Session): A Flywheel Session.
        label (str): The Acquisition label.
        update (bool): If true, update container with key/value passed as kwargs.        
        kwargs (dict): Any key/value properties of Acquisition you would like to update.

    Returns:
        (flywheel.Acquisition): A Flywheel Acquisition container.
    """
    
    if not label:
        raise ValueError(f'label is required (currently {label})')
        
    acquisition = session.acquisitions.find_first(f'label={label}')
    if not acquisition:
        acquisition = session.add_acquisition(label=label)
        
    if update and kwargs:
        acquisition.update(**kwargs)

    if acquisition:
        acquisition = acquisition.reload()

    return acquisition

# %%
def upload_file_to_acquistion(acquistion, fp, update=True, **kwargs):
    """Upload file to Acquisition container and update info if `update=True`
    
    Args:
        acquisition (flywheel.Acquisition): A Flywheel Acquisition
        fp (Path-like): Path to file to upload
        update (bool): If true, update container with key/value passed as kwargs.        
        kwargs (dict): Any key/value properties of Acquisition you would like to update.        
    """
    basename = os.path.basename(fp)
    if not os.path.isfile(fp):
        raise ValueError(f'{fp} is not file.')
        
    if acquistion.get_file(basename):
        log.info(f'File {basename} already exists in container. Skipping.')
        return
    else:
        log.info(f'Uploading {fp} to acquisition {acquistion.id}')
        acquistion.upload_file(fp)
        while not acquistion.get_file(basename):   # to make sure the file is available before performing an update
            acquistion = acquistion.reload()
            time.sleep(1)
            
    if update and kwargs:
        f = acquisition.get_file(basename)
        f.update(**kwargs)

# %% [markdown]
# ### Upload the data
# I called `organizeAndReorient.sh` before this to put the files we want into acquisition directories underneath the session folders. The Flywheel script with create acquisitions from these folders and ignore the loose files which we don't need. These folders include the following files (e.g):
#
# ```
# 2018-04-12
# │
# └───FLAIR
# │   │   2018-04-12_011_S_6303_flair.nii.gz
# │   │   2018-04-12_011_S_6303_reorient_flair.nii.gz
# │   │   2018-04-12_011_S_6303_reorient_10_flair.nii.gz
# │
# │
# └───T1w
#     │   2018-04-12_011_S_6303_T1w_trim_to_flair.nii.gz
#     │   2018-04-12_011_S_6303_reorient_T1w_trim_to_flair.nii.gz
#     │   2018-04-12_011_S_6303_reorient_10_T1w_trim_to_flair.nii.gz
#  ```
#
#  where the original FLAIR and T1w files are modified with `fslreorient2std` to bring them into a format that SYSU2 can work with and scaled by a factor of 10.

# %%
log.info('Starting upload...')
for subj in PATH_TO_DATA.glob('*S*'): # e.g., 
    log.info('Processing subject %s', str(subj))
    subject = get_or_create_subject(project, subj.name, update=True, type='human', cohort='test')  # passing some value for the sake of the example
    for ses in subj.glob('20*'): # 2017, 2018, etc.
        log.info('Processing session %s', str(ses))
        session = get_or_create_session(subject, ses.name)
        acqs = list(ses.glob('FLAIR')) + list(ses.glob('T1w')) # only need these folders
        for acq in acqs:            
            log.info('Processing acquisition %s', str(acq))
            acquisition = get_or_create_acquisition(session, acq.name)
            for file in acq.glob('*.nii.gz'):
                upload_file_to_acquistion(acquisition, file)
                
log.info('DONE')
# Out:
# 2021-09-20 13:18:07,180 INFO Starting upload...
# 2021-09-20 13:18:07,182 INFO Processing subject test-data/027_S_6034
# 2021-09-20 13:18:07,182 INFO Processing session test-data/027_S_6034/2019-07-24
# 2021-09-20 13:18:07,183 INFO Processing acquisition test-data/027_S_6034/2019-07-24/FLAIR
# 2021-09-20 13:18:07,183 INFO Processing acquisition test-data/027_S_6034/2019-07-24/T1w
# 2021-09-20 13:18:07,184 INFO Processing subject test-data/168_S_6426
# 2021-09-20 13:18:07,185 INFO Processing session test-data/168_S_6426/2018-06-29
# 2021-09-20 13:18:07,186 INFO Processing acquisition test-data/168_S_6426/2018-06-29/FLAIR
# 2021-09-20 13:18:07,187 INFO Processing acquisition test-data/168_S_6426/2018-06-29/T1w
# 2021-09-20 13:18:07,187 INFO Processing subject test-data/027_S_5277
# 2021-09-20 13:18:07,188 INFO Processing session test-data/027_S_5277/2017-11-30
# 2021-09-20 13:18:07,189 INFO Processing acquisition test-data/027_S_5277/2017-11-30/FLAIR
# 2021-09-20 13:18:07,189 INFO Processing acquisition test-data/027_S_5277/2017-11-30/T1w
# 2021-09-20 13:18:07,190 INFO Processing subject test-data/114_S_6347
# 2021-09-20 13:18:07,193 INFO Processing session test-data/114_S_6347/2018-05-26
# 2021-09-20 13:18:07,194 INFO Processing acquisition test-data/114_S_6347/2018-05-26/FLAIR
# 2021-09-20 13:18:07,195 INFO Processing acquisition test-data/114_S_6347/2018-05-26/T1w
# 2021-09-20 13:18:07,196 INFO Processing subject test-data/011_S_6303
# 2021-09-20 13:18:07,196 INFO Processing session test-data/011_S_6303/2018-04-12
# 2021-09-20 13:18:07,197 INFO Processing acquisition test-data/011_S_6303/2018-04-12/FLAIR
# 2021-09-20 13:18:07,210 INFO Processing acquisition test-data/011_S_6303/2018-04-12/T1w
# 2021-09-20 13:18:07,219 INFO Processing subject test-data/068_S_4067
# 2021-09-20 13:18:07,220 INFO Processing session test-data/068_S_4067/2017-08-16
# 2021-09-20 13:18:07,222 INFO Processing acquisition test-data/068_S_4067/2017-08-16/FLAIR
# 2021-09-20 13:18:07,224 INFO Processing acquisition test-data/068_S_4067/2017-08-16/T1w
# 2021-09-20 13:18:07,226 INFO Processing subject test-data/016_S_6789
# 2021-09-20 13:18:07,229 INFO Processing session test-data/016_S_6789/2019-07-29
# 2021-09-20 13:18:07,231 INFO Processing acquisition test-data/016_S_6789/2019-07-29/FLAIR
# 2021-09-20 13:18:07,233 INFO Processing acquisition test-data/016_S_6789/2019-07-29/T1w
# 2021-09-20 13:18:07,235 INFO Processing subject test-data/135_S_6284
# 2021-09-20 13:18:07,241 INFO Processing session test-data/135_S_6284/2018-05-02
# 2021-09-20 13:18:07,243 INFO Processing acquisition test-data/135_S_6284/2018-05-02/FLAIR
# 2021-09-20 13:18:07,248 INFO Processing acquisition test-data/135_S_6284/2018-05-02/T1w
# 2021-09-20 13:18:07,249 INFO Processing subject test-data/130_S_6047
# 2021-09-20 13:18:07,249 INFO Processing session test-data/130_S_6047/2017-07-27
# 2021-09-20 13:18:07,250 INFO Processing acquisition test-data/130_S_6047/2017-07-27/FLAIR
# 2021-09-20 13:18:07,251 INFO Processing acquisition test-data/130_S_6047/2017-07-27/T1w
# 2021-09-20 13:18:07,251 INFO Processing subject test-data/126_S_4891
# 2021-09-20 13:18:07,252 INFO Processing session test-data/126_S_4891/2018-07-27
# 2021-09-20 13:18:07,253 INFO Processing acquisition test-data/126_S_4891/2018-07-27/FLAIR
# 2021-09-20 13:18:07,254 INFO Processing acquisition test-data/126_S_4891/2018-07-27/T1w
# 2021-09-20 13:18:07,254 INFO Processing subject test-data/036_S_6231
# 2021-09-20 13:18:07,255 INFO Processing session test-data/036_S_6231/2018-03-05
# 2021-09-20 13:18:07,256 INFO Processing acquisition test-data/036_S_6231/2018-03-05/FLAIR
# 2021-09-20 13:18:07,256 INFO Processing acquisition test-data/036_S_6231/2018-03-05/T1w
# 2021-09-20 13:18:07,257 INFO Processing subject test-data/301_S_6592
# 2021-09-20 13:18:07,257 INFO Processing session test-data/301_S_6592/2018-10-23
# 2021-09-20 13:18:07,259 INFO Processing acquisition test-data/301_S_6592/2018-10-23/FLAIR
# 2021-09-20 13:18:07,260 INFO Processing acquisition test-data/301_S_6592/2018-10-23/T1w
# 2021-09-20 13:18:07,260 INFO Processing subject test-data/135_S_4489
# 2021-09-20 13:18:07,261 INFO Processing session test-data/135_S_4489/2018-06-01
# 2021-09-20 13:18:07,261 INFO Processing acquisition test-data/135_S_4489/2018-06-01/FLAIR
# 2021-09-20 13:18:07,261 INFO Processing acquisition test-data/135_S_4489/2018-06-01/T1w
# 2021-09-20 13:18:07,262 INFO Processing subject test-data/029_S_4290
# 2021-09-20 13:18:07,263 INFO Processing session test-data/029_S_4290/2018-06-12
# 2021-09-20 13:18:07,264 INFO Processing acquisition test-data/029_S_4290/2018-06-12/FLAIR
# 2021-09-20 13:18:07,265 INFO Processing acquisition test-data/029_S_4290/2018-06-12/T1w
# 2021-09-20 13:18:07,265 INFO Processing subject test-data/127_S_4197
# 2021-09-20 13:18:07,266 INFO Processing session test-data/127_S_4197/2017-09-15
# 2021-09-20 13:18:07,267 INFO Processing acquisition test-data/127_S_4197/2017-09-15/FLAIR
# 2021-09-20 13:18:07,268 INFO Processing acquisition test-data/127_S_4197/2017-09-15/T1w
# 2021-09-20 13:18:07,269 INFO Processing subject test-data/067_S_6529
# 2021-09-20 13:18:07,270 INFO Processing session test-data/067_S_6529/2018-08-14
# 2021-09-20 13:18:07,272 INFO Processing acquisition test-data/067_S_6529/2018-08-14/FLAIR
# 2021-09-20 13:18:07,273 INFO Processing acquisition test-data/067_S_6529/2018-08-14/T1w
# 2021-09-20 13:18:07,274 INFO Processing subject test-data/037_S_0377
# 2021-09-20 13:18:07,275 INFO Processing session test-data/037_S_0377/2017-04-07
# 2021-09-20 13:18:07,275 INFO Processing acquisition test-data/037_S_0377/2017-04-07/FLAIR
# 2021-09-20 13:18:07,276 INFO Processing acquisition test-data/037_S_0377/2017-04-07/T1w
# 2021-09-20 13:18:07,276 INFO Processing subject test-data/094_S_4162
# 2021-09-20 13:18:07,277 INFO Processing session test-data/094_S_4162/2015-10-06
# 2021-09-20 13:18:07,277 INFO Processing acquisition test-data/094_S_4162/2015-10-06/FLAIR
# 2021-09-20 13:18:07,278 INFO Processing acquisition test-data/094_S_4162/2015-10-06/T1w
# 2021-09-20 13:18:07,279 INFO Processing subject test-data/941_S_6345
# 2021-09-20 13:18:07,279 INFO Processing session test-data/941_S_6345/2018-05-10
# 2021-09-20 13:18:07,280 INFO Processing acquisition test-data/941_S_6345/2018-05-10/FLAIR
# 2021-09-20 13:18:07,280 INFO Processing acquisition test-data/941_S_6345/2018-05-10/T1w
# 2021-09-20 13:18:07,281 INFO Processing subject test-data/098_S_0896
# 2021-09-20 13:18:07,281 INFO Processing session test-data/098_S_0896/2018-03-15
# 2021-09-20 13:18:07,283 INFO Processing acquisition test-data/098_S_0896/2018-03-15/FLAIR
# 2021-09-20 13:18:07,284 INFO Processing acquisition test-data/098_S_0896/2018-03-15/T1w
# 2021-09-20 13:18:07,286 INFO DONE
# test-data/027_S_6034/2019-07-24/FLAIR/2019-07-24_027_S_6034_flair.nii.gz
# test-data/027_S_6034/2019-07-24/T1w/2019-07-24_027_S_6034_T1w_trim_to_flair.nii.gz
# test-data/168_S_6426/2018-06-29/FLAIR/2018-06-29_168_S_6426_flair.nii.gz
# test-data/168_S_6426/2018-06-29/T1w/2018-06-29_168_S_6426_T1w_trim_to_flair.nii.gz
# test-data/027_S_5277/2017-11-30/FLAIR/2017-11-30_027_S_5277_flair.nii.gz
# test-data/027_S_5277/2017-11-30/T1w/2017-11-30_027_S_5277_T1w_trim_to_flair.nii.gz
# test-data/114_S_6347/2018-05-26/FLAIR/2018-05-26_114_S_6347_flair.nii.gz
# test-data/114_S_6347/2018-05-26/T1w/2018-05-26_114_S_6347_T1w_trim_to_flair.nii.gz
# test-data/011_S_6303/2018-04-12/FLAIR/2018-04-12_011_S_6303_flair.nii.gz
# test-data/011_S_6303/2018-04-12/T1w/2018-04-12_011_S_6303_T1w_trim_to_flair.nii.gz
# test-data/068_S_4067/2017-08-16/FLAIR/2017-08-16_068_S_4067_flair.nii.gz
# test-data/068_S_4067/2017-08-16/T1w/2017-08-16_068_S_4067_T1w_trim_to_flair.nii.gz
# test-data/016_S_6789/2019-07-29/FLAIR/2019-07-29_016_S_6789_flair.nii.gz
# test-data/016_S_6789/2019-07-29/T1w/2019-07-29_016_S_6789_T1w_trim_to_flair.nii.gz
# test-data/135_S_6284/2018-05-02/FLAIR/2018-05-02_135_S_6284_flair.nii.gz
# test-data/135_S_6284/2018-05-02/T1w/2018-05-02_135_S_6284_T1w_trim_to_flair.nii.gz
# test-data/130_S_6047/2017-07-27/FLAIR/2017-07-27_130_S_6047_flair.nii.gz
# test-data/130_S_6047/2017-07-27/T1w/2017-07-27_130_S_6047_T1w_trim_to_flair.nii.gz
# test-data/126_S_4891/2018-07-27/FLAIR/2018-07-27_126_S_4891_flair.nii.gz
# test-data/126_S_4891/2018-07-27/T1w/2018-07-27_126_S_4891_T1w_trim_to_flair.nii.gz
# test-data/036_S_6231/2018-03-05/FLAIR/2018-03-05_036_S_6231_flair.nii.gz
# test-data/036_S_6231/2018-03-05/T1w/2018-03-05_036_S_6231_T1w_trim_to_flair.nii.gz
# test-data/301_S_6592/2018-10-23/FLAIR/2018-10-23_301_S_6592_flair.nii.gz
# test-data/301_S_6592/2018-10-23/T1w/2018-10-23_301_S_6592_T1w_trim_to_flair.nii.gz
# test-data/135_S_4489/2018-06-01/FLAIR/2018-06-01_135_S_4489_flair.nii.gz
# test-data/135_S_4489/2018-06-01/T1w/2018-06-01_135_S_4489_T1w_trim_to_flair.nii.gz
# test-data/029_S_4290/2018-06-12/FLAIR/2018-06-12_029_S_4290_flair.nii.gz
# test-data/029_S_4290/2018-06-12/T1w/2018-06-12_029_S_4290_T1w_trim_to_flair.nii.gz
# test-data/127_S_4197/2017-09-15/FLAIR/2017-09-15_127_S_4197_flair.nii.gz
# test-data/127_S_4197/2017-09-15/T1w/2017-09-15_127_S_4197_T1w_trim_to_flair.nii.gz
# test-data/067_S_6529/2018-08-14/FLAIR/2018-08-14_067_S_6529_flair.nii.gz
# test-data/067_S_6529/2018-08-14/T1w/2018-08-14_067_S_6529_T1w_trim_to_flair.nii.gz
# test-data/037_S_0377/2017-04-07/FLAIR/2017-04-07_037_S_0377_flair.nii.gz
# test-data/037_S_0377/2017-04-07/T1w/2017-04-07_037_S_0377_T1w_trim_to_flair.nii.gz
# test-data/094_S_4162/2015-10-06/FLAIR/2015-10-06_094_S_4162_flair.nii.gz
# test-data/094_S_4162/2015-10-06/T1w/2015-10-06_094_S_4162_T1w_trim_to_flair.nii.gz
# test-data/941_S_6345/2018-05-10/FLAIR/2018-05-10_941_S_6345_flair.nii.gz
# test-data/941_S_6345/2018-05-10/T1w/2018-05-10_941_S_6345_T1w_trim_to_flair.nii.gz
# test-data/098_S_0896/2018-03-15/FLAIR/2018-03-15_098_S_0896_flair.nii.gz
# test-data/098_S_0896/2018-03-15/T1w/2018-03-15_098_S_0896_T1w_trim_to_flair.nii.gz
