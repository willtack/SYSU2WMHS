# %% [markdown]
# ## Upload example data
# The purpose of the notebooks in this folder are to test the performance of the SYSU2 algorithm using Flywheel. First, we need to upload the data from this BOX folder: https://upenn.app.box.com/s/yhrwuy6x1iqcu0n81zimrrd6jvmyglmx/folder/140187582132 in a structured way.

# %%
# Import packages
import logging
import os
from pathlib import Path
import re
import time
import flywheel

# %%
# Instantiate a logger
logging.basicConfig(level=logging.INFO, format='%(asctime)s %(levelname)s %(message)s')
log = logging.getLogger('root')

# %%
# Instantiate the Flywheel API client
fw = flywheel.Client()

# %%
# Initialize some values
PROJECT_LABEL = 'WMHtestgearSYSU2'
GROUP_LABEL = 'detre_group'
PATH_TO_DATA = Path('test-data')

group = fw.lookup(GROUP_LABEL)
project = group.projects.find_first(f'label={PROJECT_LABEL}')

# %%
def get_or_create_subject(project, label, update=True, **kwargs):
    """Get the Subject container if it exists, else create a new Subject container.
    
    Args:
        project (flywheel.Project): A Flywheel Project.
        label (str): The subject label.
        update (bool): If true, update container with key/value passed as kwargs.
        kwargs (dict): Any key/value properties of subject you would like to update.

    Returns:
        (flywheel.Subject): A Flywheel Subject container.
    """
    
    if not label:
        raise ValueError(f'label is required (currently {label})')
        
    subject = project.subjects.find_first(f'label={label}')
    if not subject:
        subject = project.add_subject(label=label)
        
    if update and kwargs:
        subject.update(**kwargs)

    if subject:
        subject = subject.reload()

    return subject

# %%
def get_or_create_session(subject, label, update=True, **kwargs):
    """Get the Session container if it exists, else create a new Session container.
    
    Args:
        subject (flywheel.Subject): A Flywheel Subject.
        label (str): The session label.
        update (bool): If true, update container with key/value passed as kwargs.        
        kwargs (dict): Any key/value properties of Session you would like to update.

    Returns:
        (flywheel.Session): A flywheel Session container.
    """
    
    if not label:
        raise ValueError(f'label is required (currently {label})')
        
    session = subject.sessions.find_first(f'label={label}')
    if not session:
        session = subject.add_session(label=label)
        
    if update and kwargs:
        session.update(**kwargs)

    if session:
        session = session.reload()

    return session

# %%
def get_or_create_acquisition(session, label, update=True, **kwargs):
    """Get the Acquisition container if it exists, else create a new Acquisition container.
    
    Args:
        session (flywheel.Session): A Flywheel Session.
        label (str): The Acquisition label.
        update (bool): If true, update container with key/value passed as kwargs.        
        kwargs (dict): Any key/value properties of Acquisition you would like to update.

    Returns:
        (flywheel.Acquisition): A Flywheel Acquisition container.
    """
    
    if not label:
        raise ValueError(f'label is required (currently {label})')
        
    acquisition = session.acquisitions.find_first(f'label={label}')
    if not acquisition:
        acquisition = session.add_acquisition(label=label)
        
    if update and kwargs:
        acquisition.update(**kwargs)

    if acquisition:
        acquisition = acquisition.reload()

    return acquisition

# %%
def upload_file_to_acquistion(acquistion, fp, update=True, **kwargs):
    """Upload file to Acquisition container and update info if `update=True`
    
    Args:
        acquisition (flywheel.Acquisition): A Flywheel Acquisition
        fp (Path-like): Path to file to upload
        update (bool): If true, update container with key/value passed as kwargs.        
        kwargs (dict): Any key/value properties of Acquisition you would like to update.        
    """
    basename = os.path.basename(fp)
    if not os.path.isfile(fp):
        raise ValueError(f'{fp} is not file.')
        
    if acquistion.get_file(basename):
        log.info(f'File {basename} already exists in container. Skipping.')
        return
    else:
        log.info(f'Uploading {fp} to acquisition {acquistion.id}')
        acquistion.upload_file(fp)
        while not acquistion.get_file(basename):   # to make sure the file is available before performing an update
            acquistion = acquistion.reload()
            time.sleep(1)
            
    if update and kwargs:
        f = acquisition.get_file(basename)
        f.update(**kwargs)

# %% [markdown]
# ### Upload the data
# I called `organizeAndReorient.sh` before this to put the files we want into acquisition directories underneath the session folders. The Flywheel script will create acquisitions from these folders and ignore the loose files which we don't need. These folders include the following files (e.g):
#
# ```
# 2018-04-12
# │
# └───FLAIR
# │   │   2018-04-12_011_S_6303_flair.nii.gz
# │   │   2018-04-12_011_S_6303_reorient_flair.nii.gz
# │   │   2018-04-12_011_S_6303_reorient_10_flair.nii.gz
# │
# │
# └───T1w
#     │   2018-04-12_011_S_6303_T1w_trim_to_flair.nii.gz
#     │   2018-04-12_011_S_6303_reorient_T1w_trim_to_flair.nii.gz
#     │   2018-04-12_011_S_6303_reorient_10_T1w_trim_to_flair.nii.gz
#  ```
#
#  where the original FLAIR and T1w files are modified with `fslreorient2std` to bring them into a format that SYSU2 can work with and scaled by a factor of 10.

# %%
log.info('Starting upload...')
for subj in PATH_TO_DATA.glob('*S*'): # e.g., 
    log.info('Processing subject %s', str(subj))
    subject = get_or_create_subject(project, subj.name, update=True, type='human', cohort='Test')  # passing some value for the sake of the example
    for ses in subj.glob('20*'): # 2017, 2018, etc.
        log.info('Processing session %s', str(ses))
        session = get_or_create_session(subject, ses.name)
        acqs = list(ses.glob('FLAIR')) + list(ses.glob('T1w')) # only need these folders
        for acq in acqs:            
            log.info('Processing acquisition %s', str(acq))
            acquisition = get_or_create_acquisition(session, acq.name)
            for file in acq.glob('*.nii.gz'):
                upload_file_to_acquistion(acquisition, file)
                
log.info('DONE')
# Out:
# 2021-09-20 14:39:42,062 INFO Starting upload...
# 2021-09-20 14:39:42,063 INFO Processing subject test-data/027_S_6034
# 2021-09-20 14:39:42,285 INFO Processing session test-data/027_S_6034/2019-07-24
# 2021-09-20 14:39:42,855 INFO Processing acquisition test-data/027_S_6034/2019-07-24/FLAIR
# 2021-09-20 14:39:43,155 INFO Uploading test-data/027_S_6034/2019-07-24/FLAIR/2019-07-24_027_S_6034_flair.nii.gz to acquisition 6148d56e5f55b7686006a4fa
# 2021-09-20 14:39:49,720 INFO Uploading test-data/027_S_6034/2019-07-24/FLAIR/2019-07-24_027_S_6034_reorient_flair.nii.gz to acquisition 6148d56e5f55b7686006a4fa
# 2021-09-20 14:39:53,203 INFO Uploading test-data/027_S_6034/2019-07-24/FLAIR/2019-07-24_027_S_6034_reorient_10_flair.nii.gz to acquisition 6148d56e5f55b7686006a4fa
# 2021-09-20 14:39:56,680 INFO Processing acquisition test-data/027_S_6034/2019-07-24/T1w
# 2021-09-20 14:39:56,927 INFO Uploading test-data/027_S_6034/2019-07-24/T1w/2019-07-24_027_S_6034_T1w_trim_to_flair.nii.gz to acquisition 6148d57c5f7f7d7d7206a2db
# 2021-09-20 14:40:03,131 INFO Uploading test-data/027_S_6034/2019-07-24/T1w/2019-07-24_027_S_6034_reorient_T1w_trim_to_flair.nii.gz to acquisition 6148d57c5f7f7d7d7206a2db
# 2021-09-20 14:40:10,199 INFO Processing subject test-data/168_S_6426
# 2021-09-20 14:40:10,522 INFO Processing session test-data/168_S_6426/2018-06-29
# 2021-09-20 14:40:11,016 INFO Processing acquisition test-data/168_S_6426/2018-06-29/FLAIR
# 2021-09-20 14:40:11,373 INFO Uploading test-data/168_S_6426/2018-06-29/FLAIR/2018-06-29_168_S_6426_reorient_flair.nii.gz to acquisition 6148d58bea32459d57966092
# 2021-09-20 14:40:15,155 INFO Uploading test-data/168_S_6426/2018-06-29/FLAIR/2018-06-29_168_S_6426_reorient_10_flair.nii.gz to acquisition 6148d58bea32459d57966092
# 2021-09-20 14:40:18,763 INFO Uploading test-data/168_S_6426/2018-06-29/FLAIR/2018-06-29_168_S_6426_flair.nii.gz to acquisition 6148d58bea32459d57966092
# 2021-09-20 14:40:22,493 INFO Processing acquisition test-data/168_S_6426/2018-06-29/T1w
# 2021-09-20 14:40:22,766 INFO Uploading test-data/168_S_6426/2018-06-29/T1w/2018-06-29_168_S_6426_reorient_T1w_trim_to_flair.nii.gz to acquisition 6148d596e0650a14cf965ead
# 2021-09-20 14:40:35,820 INFO Uploading test-data/168_S_6426/2018-06-29/T1w/2018-06-29_168_S_6426_T1w_trim_to_flair.nii.gz to acquisition 6148d596e0650a14cf965ead
# 2021-09-20 14:40:45,381 INFO Processing subject test-data/027_S_5277
# 2021-09-20 14:40:45,678 INFO Processing session test-data/027_S_5277/2017-11-30
# 2021-09-20 14:40:46,115 INFO Processing acquisition test-data/027_S_5277/2017-11-30/FLAIR
# 2021-09-20 14:40:46,397 INFO Uploading test-data/027_S_5277/2017-11-30/FLAIR/2017-11-30_027_S_5277_flair.nii.gz to acquisition 6148d5ae3182ef526306a0d3
# 2021-09-20 14:40:49,841 INFO Uploading test-data/027_S_5277/2017-11-30/FLAIR/2017-11-30_027_S_5277_reorient_flair.nii.gz to acquisition 6148d5ae3182ef526306a0d3
# 2021-09-20 14:40:53,226 INFO Uploading test-data/027_S_5277/2017-11-30/FLAIR/2017-11-30_027_S_5277_reorient_10_flair.nii.gz to acquisition 6148d5ae3182ef526306a0d3
# 2021-09-20 14:40:56,652 INFO Processing acquisition test-data/027_S_5277/2017-11-30/T1w
# 2021-09-20 14:40:56,896 INFO Uploading test-data/027_S_5277/2017-11-30/T1w/2017-11-30_027_S_5277_T1w_trim_to_flair.nii.gz to acquisition 6148d5b83de65e147d8f8b42
# 2021-09-20 14:41:02,721 INFO Uploading test-data/027_S_5277/2017-11-30/T1w/2017-11-30_027_S_5277_reorient_T1w_trim_to_flair.nii.gz to acquisition 6148d5b83de65e147d8f8b42
# 2021-09-20 14:41:08,066 INFO Processing subject test-data/114_S_6347
# 2021-09-20 14:41:08,440 INFO Processing session test-data/114_S_6347/2018-05-26
# 2021-09-20 14:41:08,784 INFO Processing acquisition test-data/114_S_6347/2018-05-26/FLAIR
# 2021-09-20 14:41:09,038 INFO Uploading test-data/114_S_6347/2018-05-26/FLAIR/2018-05-26_114_S_6347_flair.nii.gz to acquisition 6148d5c4cce934cc3706a342
# 2021-09-20 14:41:14,717 INFO Processing acquisition test-data/114_S_6347/2018-05-26/T1w
# 2021-09-20 14:41:14,986 INFO Uploading test-data/114_S_6347/2018-05-26/T1w/2018-05-26_114_S_6347_T1w_trim_to_flair.nii.gz to acquisition 6148d5caa786980d0d96668e
# 2021-09-20 14:41:25,474 INFO Uploading test-data/114_S_6347/2018-05-26/T1w/2018-05-26_114_S_6347_reorient_T1w_trim_to_flair.nii.gz to acquisition 6148d5caa786980d0d96668e
# 2021-09-20 14:41:39,663 INFO Processing subject test-data/011_S_6303
# 2021-09-20 14:41:39,995 INFO Processing session test-data/011_S_6303/2018-04-12
# 2021-09-20 14:41:40,368 INFO Processing acquisition test-data/011_S_6303/2018-04-12/FLAIR
# 2021-09-20 14:41:40,629 INFO Uploading test-data/011_S_6303/2018-04-12/FLAIR/2018-04-12_011_S_6303_reorient_flair.nii.gz to acquisition 6148d5e41652d8383ba4805f
# 2021-09-20 14:41:45,662 INFO Uploading test-data/011_S_6303/2018-04-12/FLAIR/2018-04-12_011_S_6303_reorient_10_flair.nii.gz to acquisition 6148d5e41652d8383ba4805f
# 2021-09-20 14:41:51,389 INFO Uploading test-data/011_S_6303/2018-04-12/FLAIR/2018-04-12_011_S_6303_flair.nii.gz to acquisition 6148d5e41652d8383ba4805f
# 2021-09-20 14:41:57,237 INFO Processing acquisition test-data/011_S_6303/2018-04-12/T1w
# 2021-09-20 14:41:57,509 INFO Uploading test-data/011_S_6303/2018-04-12/T1w/2018-04-12_011_S_6303_reorient_T1w_trim_to_flair.nii.gz to acquisition 6148d5f5fa1a633c97a479cc
# 2021-09-20 14:42:01,767 INFO Uploading test-data/011_S_6303/2018-04-12/T1w/2018-04-12_011_S_6303_T1w_trim_to_flair.nii.gz to acquisition 6148d5f5fa1a633c97a479cc
# 2021-09-20 14:42:06,446 INFO Processing subject test-data/068_S_4067
# 2021-09-20 14:42:06,761 INFO Processing session test-data/068_S_4067/2017-08-16
# 2021-09-20 14:42:07,125 INFO Processing acquisition test-data/068_S_4067/2017-08-16/FLAIR
# 2021-09-20 14:42:07,404 INFO Uploading test-data/068_S_4067/2017-08-16/FLAIR/2017-08-16_068_S_4067_reorient_flair.nii.gz to acquisition 6148d5ffe0650a14cf965f96
# 2021-09-20 14:42:13,028 INFO Uploading test-data/068_S_4067/2017-08-16/FLAIR/2017-08-16_068_S_4067_flair.nii.gz to acquisition 6148d5ffe0650a14cf965f96
# 2021-09-20 14:42:18,185 INFO Uploading test-data/068_S_4067/2017-08-16/FLAIR/2017-08-16_068_S_4067_reorient_10_flair.nii.gz to acquisition 6148d5ffe0650a14cf965f96
# 2021-09-20 14:42:23,379 INFO Processing acquisition test-data/068_S_4067/2017-08-16/T1w
# 2021-09-20 14:42:23,648 INFO Uploading test-data/068_S_4067/2017-08-16/T1w/2017-08-16_068_S_4067_reorient_T1w_trim_to_flair.nii.gz to acquisition 6148d60fe0650a14cf965f97
# 2021-09-20 14:42:33,382 INFO Uploading test-data/068_S_4067/2017-08-16/T1w/2017-08-16_068_S_4067_T1w_trim_to_flair.nii.gz to acquisition 6148d60fe0650a14cf965f97
# 2021-09-20 14:42:46,373 INFO Processing subject test-data/016_S_6789
# 2021-09-20 14:42:46,713 INFO Processing session test-data/016_S_6789/2019-07-29
# 2021-09-20 14:42:47,117 INFO Processing acquisition test-data/016_S_6789/2019-07-29/FLAIR
# 2021-09-20 14:42:47,402 INFO Uploading test-data/016_S_6789/2019-07-29/FLAIR/2019-07-29_016_S_6789_reorient_flair.nii.gz to acquisition 6148d62708a8cb553aa480fb
# 2021-09-20 14:42:51,535 INFO Uploading test-data/016_S_6789/2019-07-29/FLAIR/2019-07-29_016_S_6789_flair.nii.gz to acquisition 6148d62708a8cb553aa480fb
# 2021-09-20 14:42:55,744 INFO Uploading test-data/016_S_6789/2019-07-29/FLAIR/2019-07-29_016_S_6789_reorient_10_flair.nii.gz to acquisition 6148d62708a8cb553aa480fb
# 2021-09-20 14:42:59,599 INFO Processing acquisition test-data/016_S_6789/2019-07-29/T1w
# 2021-09-20 14:42:59,878 INFO Uploading test-data/016_S_6789/2019-07-29/T1w/2019-07-29_016_S_6789_T1w_trim_to_flair.nii.gz to acquisition 6148d63304365e7baed6a071
# 2021-09-20 14:43:10,296 INFO Uploading test-data/016_S_6789/2019-07-29/T1w/2019-07-29_016_S_6789_reorient_T1w_trim_to_flair.nii.gz to acquisition 6148d63304365e7baed6a071
# 2021-09-20 14:43:19,658 INFO Processing subject test-data/135_S_6284
# 2021-09-20 14:43:20,038 INFO Processing session test-data/135_S_6284/2018-05-02
# 2021-09-20 14:43:20,645 INFO Processing acquisition test-data/135_S_6284/2018-05-02/FLAIR
# 2021-09-20 14:43:21,024 INFO Uploading test-data/135_S_6284/2018-05-02/FLAIR/2018-05-02_135_S_6284_reorient_10_flair.nii.gz to acquisition 6148d6485f55b7686006a740
# 2021-09-20 14:43:26,426 INFO Uploading test-data/135_S_6284/2018-05-02/FLAIR/2018-05-02_135_S_6284_flair.nii.gz to acquisition 6148d6485f55b7686006a740
# 2021-09-20 14:43:31,783 INFO Uploading test-data/135_S_6284/2018-05-02/FLAIR/2018-05-02_135_S_6284_reorient_flair.nii.gz to acquisition 6148d6485f55b7686006a740
# 2021-09-20 14:43:36,728 INFO Processing acquisition test-data/135_S_6284/2018-05-02/T1w
# 2021-09-20 14:43:37,046 INFO Uploading test-data/135_S_6284/2018-05-02/T1w/2018-05-02_135_S_6284_reorient_T1w_trim_to_flair.nii.gz to acquisition 6148d6581bee39690406b5b8
# 2021-09-20 14:43:41,160 INFO Uploading test-data/135_S_6284/2018-05-02/T1w/2018-05-02_135_S_6284_T1w_trim_to_flair.nii.gz to acquisition 6148d6581bee39690406b5b8
# 2021-09-20 14:43:44,861 INFO Processing subject test-data/130_S_6047
# 2021-09-20 14:43:45,229 INFO Processing session test-data/130_S_6047/2017-07-27
# 2021-09-20 14:43:45,736 INFO Processing acquisition test-data/130_S_6047/2017-07-27/FLAIR
# 2021-09-20 14:43:46,021 INFO Uploading test-data/130_S_6047/2017-07-27/FLAIR/2017-07-27_130_S_6047_reorient_10_flair.nii.gz to acquisition 6148d661ea32459d57966160
# 2021-09-20 14:43:49,627 INFO Uploading test-data/130_S_6047/2017-07-27/FLAIR/2017-07-27_130_S_6047_reorient_flair.nii.gz to acquisition 6148d661ea32459d57966160
# 2021-09-20 14:43:52,658 INFO Uploading test-data/130_S_6047/2017-07-27/FLAIR/2017-07-27_130_S_6047_flair.nii.gz to acquisition 6148d661ea32459d57966160
# 2021-09-20 14:43:55,578 INFO Processing acquisition test-data/130_S_6047/2017-07-27/T1w
# 2021-09-20 14:43:55,879 INFO Uploading test-data/130_S_6047/2017-07-27/T1w/2017-07-27_130_S_6047_T1w_trim_to_flair.nii.gz to acquisition 6148d66b8af2542a44966822
# 2021-09-20 14:44:02,170 INFO Uploading test-data/130_S_6047/2017-07-27/T1w/2017-07-27_130_S_6047_reorient_T1w_trim_to_flair.nii.gz to acquisition 6148d66b8af2542a44966822
# 2021-09-20 14:44:07,986 INFO Processing subject test-data/126_S_4891
# 2021-09-20 14:44:08,401 INFO Processing session test-data/126_S_4891/2018-07-27
# 2021-09-20 14:44:08,883 INFO Processing acquisition test-data/126_S_4891/2018-07-27/FLAIR
# 2021-09-20 14:44:09,129 INFO Uploading test-data/126_S_4891/2018-07-27/FLAIR/2018-07-27_126_S_4891_reorient_flair.nii.gz to acquisition 6148d678fa1a633c97a47a05
# 2021-09-20 14:44:14,595 INFO Uploading test-data/126_S_4891/2018-07-27/FLAIR/2018-07-27_126_S_4891_flair.nii.gz to acquisition 6148d678fa1a633c97a47a05
# 2021-09-20 14:44:20,283 INFO Uploading test-data/126_S_4891/2018-07-27/FLAIR/2018-07-27_126_S_4891_reorient_10_flair.nii.gz to acquisition 6148d678fa1a633c97a47a05
# 2021-09-20 14:44:25,655 INFO Processing acquisition test-data/126_S_4891/2018-07-27/T1w
# 2021-09-20 14:44:25,914 INFO Uploading test-data/126_S_4891/2018-07-27/T1w/2018-07-27_126_S_4891_reorient_T1w_trim_to_flair.nii.gz to acquisition 6148d689081f48d05da47d6b
# 2021-09-20 14:44:35,279 INFO Uploading test-data/126_S_4891/2018-07-27/T1w/2018-07-27_126_S_4891_T1w_trim_to_flair.nii.gz to acquisition 6148d689081f48d05da47d6b
# 2021-09-20 14:44:45,056 INFO Processing subject test-data/036_S_6231
# 2021-09-20 14:44:45,427 INFO Processing session test-data/036_S_6231/2018-03-05
# 2021-09-20 14:44:46,134 INFO Processing acquisition test-data/036_S_6231/2018-03-05/FLAIR
# 2021-09-20 14:44:46,409 INFO Uploading test-data/036_S_6231/2018-03-05/FLAIR/2018-03-05_036_S_6231_flair.nii.gz to acquisition 6148d69ec3eb6275d5d69a6a
# 2021-09-20 14:44:50,631 INFO Uploading test-data/036_S_6231/2018-03-05/FLAIR/2018-03-05_036_S_6231_reorient_flair.nii.gz to acquisition 6148d69ec3eb6275d5d69a6a
# 2021-09-20 14:44:54,202 INFO Uploading test-data/036_S_6231/2018-03-05/FLAIR/2018-03-05_036_S_6231_reorient_10_flair.nii.gz to acquisition 6148d69ec3eb6275d5d69a6a
# 2021-09-20 14:44:58,137 INFO Processing acquisition test-data/036_S_6231/2018-03-05/T1w
# 2021-09-20 14:44:58,474 INFO Uploading test-data/036_S_6231/2018-03-05/T1w/2018-03-05_036_S_6231_reorient_T1w_trim_to_flair.nii.gz to acquisition 6148d6aad8a81f6832d69393
# 2021-09-20 14:45:08,466 INFO Uploading test-data/036_S_6231/2018-03-05/T1w/2018-03-05_036_S_6231_T1w_trim_to_flair.nii.gz to acquisition 6148d6aad8a81f6832d69393
# 2021-09-20 14:45:18,456 INFO Processing subject test-data/301_S_6592
# 2021-09-20 14:45:19,485 INFO Processing session test-data/301_S_6592/2018-10-23
# 2021-09-20 14:45:19,957 INFO Processing acquisition test-data/301_S_6592/2018-10-23/FLAIR
# 2021-09-20 14:45:20,212 INFO Uploading test-data/301_S_6592/2018-10-23/FLAIR/2018-10-23_301_S_6592_reorient_flair.nii.gz to acquisition 6148d6c08af2542a44966829
# 2021-09-20 14:45:24,920 INFO Uploading test-data/301_S_6592/2018-10-23/FLAIR/2018-10-23_301_S_6592_flair.nii.gz to acquisition 6148d6c08af2542a44966829
# 2021-09-20 14:45:29,013 INFO Uploading test-data/301_S_6592/2018-10-23/FLAIR/2018-10-23_301_S_6592_reorient_10_flair.nii.gz to acquisition 6148d6c08af2542a44966829
# 2021-09-20 14:45:33,341 INFO Processing acquisition test-data/301_S_6592/2018-10-23/T1w
# 2021-09-20 14:45:33,654 INFO Uploading test-data/301_S_6592/2018-10-23/T1w/2018-10-23_301_S_6592_T1w_trim_to_flair.nii.gz to acquisition 6148d6cdccdb89aff1965d98
# 2021-09-20 14:45:44,500 INFO Uploading test-data/301_S_6592/2018-10-23/T1w/2018-10-23_301_S_6592_reorient_T1w_trim_to_flair.nii.gz to acquisition 6148d6cdccdb89aff1965d98
# 2021-09-20 14:45:55,639 INFO Processing subject test-data/135_S_4489
# 2021-09-20 14:45:55,939 INFO Processing session test-data/135_S_4489/2018-06-01
# 2021-09-20 14:45:56,270 INFO Processing acquisition test-data/135_S_4489/2018-06-01/FLAIR
# 2021-09-20 14:45:56,501 INFO Uploading test-data/135_S_4489/2018-06-01/FLAIR/2018-06-01_135_S_4489_flair.nii.gz to acquisition 6148d6e47933967dc2a475b1
# 2021-09-20 14:46:01,264 INFO Uploading test-data/135_S_4489/2018-06-01/FLAIR/2018-06-01_135_S_4489_reorient_flair.nii.gz to acquisition 6148d6e47933967dc2a475b1
# 2021-09-20 14:46:06,684 INFO Uploading test-data/135_S_4489/2018-06-01/FLAIR/2018-06-01_135_S_4489_reorient_10_flair.nii.gz to acquisition 6148d6e47933967dc2a475b1
# 2021-09-20 14:46:11,584 INFO Processing acquisition test-data/135_S_4489/2018-06-01/T1w
# 2021-09-20 14:46:11,831 INFO Uploading test-data/135_S_4489/2018-06-01/T1w/2018-06-01_135_S_4489_reorient_T1w_trim_to_flair.nii.gz to acquisition 6148d6f3fa1a633c97a47aea
# 2021-09-20 14:46:31,225 INFO Uploading test-data/135_S_4489/2018-06-01/T1w/2018-06-01_135_S_4489_T1w_trim_to_flair.nii.gz to acquisition 6148d6f3fa1a633c97a47aea
# 2021-09-20 14:46:39,964 INFO Processing subject test-data/029_S_4290
# 2021-09-20 14:46:40,309 INFO Processing session test-data/029_S_4290/2018-06-12
# 2021-09-20 14:46:40,668 INFO Processing acquisition test-data/029_S_4290/2018-06-12/FLAIR
# 2021-09-20 14:46:40,921 INFO Uploading test-data/029_S_4290/2018-06-12/FLAIR/2018-06-12_029_S_4290_flair.nii.gz to acquisition 6148d710d8a81f6832d693c8
# 2021-09-20 14:46:47,341 INFO Uploading test-data/029_S_4290/2018-06-12/FLAIR/2018-06-12_029_S_4290_reorient_flair.nii.gz to acquisition 6148d710d8a81f6832d693c8
# 2021-09-20 14:46:54,551 INFO Uploading test-data/029_S_4290/2018-06-12/FLAIR/2018-06-12_029_S_4290_reorient_10_flair.nii.gz to acquisition 6148d710d8a81f6832d693c8
# 2021-09-20 14:47:02,475 INFO Processing acquisition test-data/029_S_4290/2018-06-12/T1w
# 2021-09-20 14:47:02,737 INFO Uploading test-data/029_S_4290/2018-06-12/T1w/2018-06-12_029_S_4290_reorient_T1w_trim_to_flair.nii.gz to acquisition 6148d72622f7c6ffe5d699f6
# 2021-09-20 14:47:10,643 INFO Uploading test-data/029_S_4290/2018-06-12/T1w/2018-06-12_029_S_4290_T1w_trim_to_flair.nii.gz to acquisition 6148d72622f7c6ffe5d699f6
# 2021-09-20 14:47:19,969 INFO Processing subject test-data/127_S_4197
# 2021-09-20 14:47:20,282 INFO Processing session test-data/127_S_4197/2017-09-15
# 2021-09-20 14:47:20,730 INFO Processing acquisition test-data/127_S_4197/2017-09-15/FLAIR
# 2021-09-20 14:47:21,050 INFO Uploading test-data/127_S_4197/2017-09-15/FLAIR/2017-09-15_127_S_4197_reorient_10_flair.nii.gz to acquisition 6148d738ca3ba7a3088f8ab6
# 2021-09-20 14:47:24,122 INFO Uploading test-data/127_S_4197/2017-09-15/FLAIR/2017-09-15_127_S_4197_flair.nii.gz to acquisition 6148d738ca3ba7a3088f8ab6
# 2021-09-20 14:47:27,632 INFO Uploading test-data/127_S_4197/2017-09-15/FLAIR/2017-09-15_127_S_4197_reorient_flair.nii.gz to acquisition 6148d738ca3ba7a3088f8ab6
# 2021-09-20 14:47:31,092 INFO Processing acquisition test-data/127_S_4197/2017-09-15/T1w
# 2021-09-20 14:47:31,462 INFO Uploading test-data/127_S_4197/2017-09-15/T1w/2017-09-15_127_S_4197_reorient_T1w_trim_to_flair.nii.gz to acquisition 6148d743b11489d6cc8f86ca
# 2021-09-20 14:47:37,657 INFO Uploading test-data/127_S_4197/2017-09-15/T1w/2017-09-15_127_S_4197_T1w_trim_to_flair.nii.gz to acquisition 6148d743b11489d6cc8f86ca
# 2021-09-20 14:47:44,397 INFO Processing subject test-data/067_S_6529
# 2021-09-20 14:47:44,735 INFO Processing session test-data/067_S_6529/2018-08-14
# 2021-09-20 14:47:45,254 INFO Processing acquisition test-data/067_S_6529/2018-08-14/FLAIR
# 2021-09-20 14:47:45,533 INFO Uploading test-data/067_S_6529/2018-08-14/FLAIR/2018-08-14_067_S_6529_reorient_flair.nii.gz to acquisition 6148d7516f88a9b561d6b210
# 2021-09-20 14:47:49,473 INFO Uploading test-data/067_S_6529/2018-08-14/FLAIR/2018-08-14_067_S_6529_reorient_10_flair.nii.gz to acquisition 6148d7516f88a9b561d6b210
# 2021-09-20 14:47:54,000 INFO Uploading test-data/067_S_6529/2018-08-14/FLAIR/2018-08-14_067_S_6529_flair.nii.gz to acquisition 6148d7516f88a9b561d6b210
# 2021-09-20 14:47:58,368 INFO Processing acquisition test-data/067_S_6529/2018-08-14/T1w
# 2021-09-20 14:47:58,670 INFO Uploading test-data/067_S_6529/2018-08-14/T1w/2018-08-14_067_S_6529_T1w_trim_to_flair.nii.gz to acquisition 6148d75ed8a81f6832d693f3
# 2021-09-20 14:48:02,176 INFO Uploading test-data/067_S_6529/2018-08-14/T1w/2018-08-14_067_S_6529_reorient_T1w_trim_to_flair.nii.gz to acquisition 6148d75ed8a81f6832d693f3
# 2021-09-20 14:48:06,059 INFO Processing subject test-data/037_S_0377
# 2021-09-20 14:48:06,395 INFO Processing session test-data/037_S_0377/2017-04-07
# 2021-09-20 14:48:06,814 INFO Processing acquisition test-data/037_S_0377/2017-04-07/FLAIR
# 2021-09-20 14:48:07,068 INFO Uploading test-data/037_S_0377/2017-04-07/FLAIR/2017-04-07_037_S_0377_reorient_10_flair.nii.gz to acquisition 6148d766bd18b4369d8f8db9
# 2021-09-20 14:48:10,327 INFO Uploading test-data/037_S_0377/2017-04-07/FLAIR/2017-04-07_037_S_0377_flair.nii.gz to acquisition 6148d766bd18b4369d8f8db9
# 2021-09-20 14:48:15,351 INFO Uploading test-data/037_S_0377/2017-04-07/FLAIR/2017-04-07_037_S_0377_reorient_flair.nii.gz to acquisition 6148d766bd18b4369d8f8db9
# 2021-09-20 14:48:29,040 INFO Processing acquisition test-data/037_S_0377/2017-04-07/T1w
# 2021-09-20 14:48:29,304 INFO Uploading test-data/037_S_0377/2017-04-07/T1w/2017-04-07_037_S_0377_T1w_trim_to_flair.nii.gz to acquisition 6148d77d94fc44e7a98f8d79
# 2021-09-20 14:48:52,656 INFO Uploading test-data/037_S_0377/2017-04-07/T1w/2017-04-07_037_S_0377_reorient_T1w_trim_to_flair.nii.gz to acquisition 6148d77d94fc44e7a98f8d79
# 2021-09-20 14:49:13,996 INFO Processing subject test-data/094_S_4162
# 2021-09-20 14:49:14,326 INFO Processing session test-data/094_S_4162/2015-10-06
# 2021-09-20 14:49:14,712 INFO Processing acquisition test-data/094_S_4162/2015-10-06/FLAIR
# 2021-09-20 14:49:14,977 INFO Uploading test-data/094_S_4162/2015-10-06/FLAIR/2015-10-06_094_S_4162_reorient_flair.nii.gz to acquisition 6148d7aa3cabf3eaf406a937
# 2021-09-20 14:49:18,879 INFO Uploading test-data/094_S_4162/2015-10-06/FLAIR/2015-10-06_094_S_4162_reorient_10_flair.nii.gz to acquisition 6148d7aa3cabf3eaf406a937
# 2021-09-20 14:49:22,218 INFO Uploading test-data/094_S_4162/2015-10-06/FLAIR/2015-10-06_094_S_4162_flair.nii.gz to acquisition 6148d7aa3cabf3eaf406a937
# 2021-09-20 14:49:25,773 INFO Processing acquisition test-data/094_S_4162/2015-10-06/T1w
# 2021-09-20 14:49:26,037 INFO Uploading test-data/094_S_4162/2015-10-06/T1w/2015-10-06_094_S_4162_reorient_T1w_trim_to_flair.nii.gz to acquisition 6148d7b53182ef526306a441
# 2021-09-20 14:49:32,577 INFO Uploading test-data/094_S_4162/2015-10-06/T1w/2015-10-06_094_S_4162_T1w_trim_to_flair.nii.gz to acquisition 6148d7b53182ef526306a441
# 2021-09-20 14:49:40,405 INFO Processing subject test-data/941_S_6345
# 2021-09-20 14:49:40,742 INFO Processing session test-data/941_S_6345/2018-05-10
# 2021-09-20 14:49:41,116 INFO Processing acquisition test-data/941_S_6345/2018-05-10/FLAIR
# 2021-09-20 14:49:41,411 INFO Uploading test-data/941_S_6345/2018-05-10/FLAIR/2018-05-10_941_S_6345_flair.nii.gz to acquisition 6148d7c5d3ad4b0d08965d0b
# 2021-09-20 14:49:51,010 INFO Uploading test-data/941_S_6345/2018-05-10/FLAIR/2018-05-10_941_S_6345_reorient_10_flair.nii.gz to acquisition 6148d7c5d3ad4b0d08965d0b
# 2021-09-20 14:49:59,111 INFO Uploading test-data/941_S_6345/2018-05-10/FLAIR/2018-05-10_941_S_6345_reorient_flair.nii.gz to acquisition 6148d7c5d3ad4b0d08965d0b
# 2021-09-20 14:50:08,807 INFO Processing acquisition test-data/941_S_6345/2018-05-10/T1w
# 2021-09-20 14:50:09,079 INFO Uploading test-data/941_S_6345/2018-05-10/T1w/2018-05-10_941_S_6345_T1w_trim_to_flair.nii.gz to acquisition 6148d7e0d8a81f6832d6946e
# 2021-09-20 14:50:14,502 INFO Uploading test-data/941_S_6345/2018-05-10/T1w/2018-05-10_941_S_6345_reorient_T1w_trim_to_flair.nii.gz to acquisition 6148d7e0d8a81f6832d6946e
# 2021-09-20 14:50:19,595 INFO Processing subject test-data/098_S_0896
# 2021-09-20 14:50:19,947 INFO Processing session test-data/098_S_0896/2018-03-15
# 2021-09-20 14:50:20,349 INFO Processing acquisition test-data/098_S_0896/2018-03-15/FLAIR
# 2021-09-20 14:50:20,587 INFO Uploading test-data/098_S_0896/2018-03-15/FLAIR/2018-03-15_098_S_0896_reorient_10_flair.nii.gz to acquisition 6148d7ec94fc44e7a98f8de5
# 2021-09-20 14:50:27,069 INFO Uploading test-data/098_S_0896/2018-03-15/FLAIR/2018-03-15_098_S_0896_flair.nii.gz to acquisition 6148d7ec94fc44e7a98f8de5
# 2021-09-20 14:50:32,340 INFO Uploading test-data/098_S_0896/2018-03-15/FLAIR/2018-03-15_098_S_0896_reorient_flair.nii.gz to acquisition 6148d7ec94fc44e7a98f8de5
# 2021-09-20 14:50:38,565 INFO Processing acquisition test-data/098_S_0896/2018-03-15/T1w
# 2021-09-20 14:50:38,808 INFO Uploading test-data/098_S_0896/2018-03-15/T1w/2018-03-15_098_S_0896_T1w_trim_to_flair.nii.gz to acquisition 6148d7fea1f6f9e04e8f8285
# 2021-09-20 14:50:53,330 INFO Uploading test-data/098_S_0896/2018-03-15/T1w/2018-03-15_098_S_0896_reorient_T1w_trim_to_flair.nii.gz to acquisition 6148d7fea1f6f9e04e8f8285
# 2021-09-20 14:51:05,204 INFO DONE
